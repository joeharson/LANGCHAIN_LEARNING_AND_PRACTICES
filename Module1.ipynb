# %%
import langchain
import os 
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate

load_dotenv()

google_api_key=os.getenv("GOOGLE_API_KEY")

llm=ChatGoogleGenerativeAI(google_api_key=google_api_key, model="gemini-2.5-flash", temperature=0.2)

'''
res=llm.invoke("what is Lang chain?")
print(res.content)
'''

prompt=PromptTemplate(
    input_variables=["input"], 
    template="you are helpful assistant. Answer the following question:{input}"
)

chain=prompt | llm
res =chain.invoke({"input":"what is Lang chain?"})
print(res.content)
# Out:
# **LangChain is an open-source framework designed to simplify the development of applications powered by large language models (LLMs).**
#
# Think of it as a toolkit that allows developers to connect LLMs with other sources of data and computation, enabling them to build more complex and powerful applications than what's possible with an LLM alone.
#
# ### Why is LangChain Needed?
#
# While LLMs are incredibly powerful, they have limitations:
# 1.  **Lack of Memory:** They don't inherently remember past interactions in a conversation.
# 2.  **Limited Knowledge:** Their knowledge is static, based on their training data, and they can't access real-time information or private documents.
# 3.  **Inability to Act:** They can generate text, but they can't directly perform actions like searching the web, running code, or interacting with APIs.
#
# LangChain addresses these limitations by providing tools to:
# *   Give LLMs **memory** for conversational context.
# *   Connect LLMs to **external data sources** (e.g., databases, documents, APIs) for up-to-date or specific information.
# *   Enable LLMs to **interact with their environment** by using tools (e.g., search engines, calculators, custom APIs).
#
# ### Key Concepts and Components of LangChain:
#
# LangChain is built around several modular components that can be combined in various ways:
#
# 1.  **Models:**
#     *   **LLMs:** Interfaces to various large language models (e.g., OpenAI's GPT series, Google's PaLM, Hugging Face models).
#     *   **Chat Models:** Specifically designed for conversational interfaces.
#     *   **Embeddings:** Tools to convert text into numerical vectors, useful for similarity searches and retrieval.
#
# 2.  **Prompts:**
#     *   **Prompt Templates:** Standardized ways to construct prompts for LLMs, making it easier to reuse and manage them.
#     *   **Output Parsers:** Tools to structure the output from LLMs into specific formats (e.g., JSON, lists).
#
# 3.  **Chains:**
#     *   The core concept of LangChain. Chains allow you to combine LLMs with other components (like prompt templates, other chains, or external tools) into a sequence of operations. This enables multi-step reasoning and complex workflows.
#     *   Examples: `LLMChain` (simple LLM call), `SequentialChain` (multiple steps), `RetrievalQAChain` (Q&A over documents).
#
# 4.  **Retrieval:**
#     *   Tools for fetching relevant data from external sources to augment the LLM's knowledge.
#     *   **Document Loaders:** Load data from various sources (PDFs, websites, databases).
#     *   **Text Splitters:** Break down large documents into smaller, manageable chunks.
#     *   **Vector Stores:** Store and search document embeddings for efficient retrieval of relevant information (e.g., Pinecone, Chroma, FAISS).
#
# 5.  **Agents:**
#     *   Agents are LLMs that can decide *what actions to take* and *what tools to use* based on user input and observations. They can dynamically chain together tools until a task is completed.
#     *   This is where the LLM becomes a "reasoning engine" that can interact with its environment.
#     *   **Tools:** Functions or APIs that an agent can use (e.g., Google Search, a calculator, a custom API).
#
# 6.  **Memory:**
#     *   Allows LLMs to remember past interactions in a conversation, providing context for ongoing dialogue.
#     *   Various types of memory: `ConversationBufferMemory`, `ConversationSummaryMemory`, etc.
#
# ### Common Use Cases for LangChain:
#
# *   **Question Answering over Documents (RAG - Retrieval Augmented Generation):** Build chatbots that can answer questions based on your private documents (e.g., company manuals, research papers).
# *   **Chatbots with Conversational Memory:** Create intelligent chatbots that remember the context of your conversation.
# *   **Agents that can Perform Actions:** Develop agents that can browse the web, execute code, interact with APIs, or perform complex multi-step tasks.
# *   **Data Extraction and Summarization:** Build pipelines to extract specific information or summarize large texts.
# *   **Code Generation and Debugging:** Use LLMs to generate code, and then use tools to test or debug it.
#
# In essence, LangChain empowers developers to move beyond simple LLM prompts and build sophisticated, data-aware, and interactive applications that leverage the full potential of large language models.
