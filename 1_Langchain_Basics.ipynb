# %% [markdown]
# ## langchain Basics

# %%
import langchain
import os 
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate

load_dotenv()

google_api_key=os.getenv("GOOGLE_API_KEY")

llm=ChatGoogleGenerativeAI(google_api_key=google_api_key, model="gemini-2.5-flash", temperature=0.2)

'''
res=llm.invoke("what is Lang chain?")
print(res.content)
'''

prompt=PromptTemplate(
    input_variables=["input"], 
    template="you are helpful assistant. Answer the following question:{input}"
)

chain=prompt | llm
res =chain.invoke({"input":"what is Lang chain?"})
print(res.content)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# LangChain is an open-source **framework** designed to help developers build applications powered by **Large Language Models (LLMs)**.
#
# Think of it this way: LLMs are incredibly powerful "brains" that can understand and generate human-like text. However, by themselves, they have limitations:
#
# *   They don't have real-time information (their knowledge is based on their training data cut-off).
# *   They can't perform actions in the real world (like searching the web, calling an API, or interacting with a database).
# *   They have limited memory of past conversations.
# *   Complex tasks often require multiple steps of reasoning or interaction.
#
# ...

# %% [markdown]
# ![module1_intro.png](attachment:module1_intro.png)
